# %%
import numpy as np
import statistics

data = np.array([1, 3, 4, 4, 5, 5, 5, 6, 9])

mean = np.mean(data) # 平均
minimum = np.min(data) # 最小値
maximum = np.max(data) # 最大値
median = np.median(data) # 中央値
mode = statistics.mode(data) # 最頻値

print('平均:', mean)
print('最小値:', minimum)
print('最大値:', maximum)
print('中央値:', median)
print('最頻値:', mode)
# Out:
# 平均: 4.66666666667
# 最小値: 1
# 最大値: 9
# 中央値: 5.0
# 最頻値: 5

# %%
import numpy as np

data = np.array([1, 3, 4, 4, 5, 5, 5, 6, 9])

var = np.var(data) # 平方和
std = np.std(data) # 標準偏差

print('平方和は:', var)
print('標準偏差は:', std)
# Out:
# 平方和は: 4.22222222222
# 標準偏差は: 2.05480466766

# %%
# 散布図
import matplotlib.pyplot as plt

science=[100, 95, 74, 70, 62, 60, 50]
math=[100, 85, 80, 65, 67, 61, 55]
plt.scatter(science, math)

plt.title('result of science and math test')
plt.xlabel('result of science test')
plt.ylabel('result of math test')
plt.show()

# %%
# 折れ線グラフ
import matplotlib.pyplot as plt

science=[100, 95, 74, 70, 62, 60, 50]
math=[100, 85, 80, 65, 67, 61, 55]
plt.plot(science, math, marker=0)
plt.title('result of science and math test')
plt.xlabel('result of science test')
plt.ylabel('result of math test')
plt.show()

# %%
# 棒グラフ
import numpy as np
import matplotlib.pyplot as plt

w = 0.25

Y1 = np.array([1600, 2400, 1800])
Y2 = np.array([2000, 2800, 2500])
Y3 = np.array([1800, 2500, 2000])
X = np.arange(len(Y1))

# 9月のデータを赤で表示
plt.bar(X, Y1, color='b', width=w, label='Tokyo', align='center')

# 10月のデータを赤で表示
plt.bar(X+w, Y2, color='g', width=w, label='Nagoya', align='center')

# 11月のデータを赤で表示
plt.bar(X+2*w, Y3, color='r', width=w, label='Osaka', align='center')

# 凡例
plt.legend(loc='best')

# X軸の目盛りを書き換える
plt.xticks(X + w/3, ['September', 'October', 'November'])

plt.show()

# %%
# 円グラフ
import numpy as np
import matplotlib.pyplot as plt

x = np.array([28.3, 15.8, 6.2, 4.8, 3.6, 41.3])
label = ["China", "America", "India", "Russia", "Japan","the others"]

plt.pie(x, labels=label, counterclock=False, startangle=90, autopct='%.1f%%', pctdistance=0.7)
plt.axis('equal')
plt.show()
